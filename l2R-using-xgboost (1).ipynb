# %% [markdown]
# # download the dataset from here:
# #https://www.microsoft.com/en-us/research/project/mslr/
#
# ### libSVM format
# read about this file format here: https://catboost.ai/docs/concepts/input-data_libsvm.html

# %%
import os
import pickle as pkl
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
import xgboost as xgb
from xgboost.testing.data import RelDataCV
from sklearn.metrics import ndcg_score, average_precision_score

# %%
def load_mlsr_10k(data_path: str, cache_path: str) -> RelDataCV:
    """Load the MSLR10k dataset from data_path and cache a pickle object in cache_path.

    Returns
    -------

    A list of tuples [(X, y, qid), ...].

    """
    root_path = os.path.expanduser('C:\MSLR-WEB10K')
    cacheroot_path = os.path.expanduser('C:\MSLR-WEB10K-cache')
    cache_path = os.path.join(cacheroot_path, 'C:\MSLR_10K_LETOR.pkl')

    # Use only the Fold1 for demo:
    # Train,      Valid, Test
    # {S1,S2,S3}, S4,    S5
    fold = 1

    if not os.path.exists(cache_path):
        fold_path = os.path.join(root_path, f"Fold{fold}")
        train_path = os.path.join(fold_path, "train.txt")
        valid_path = os.path.join(fold_path, "vali.txt")
        test_path = os.path.join(fold_path, "test.txt")
        X_train, y_train, qid_train = load_svmlight_file(
            train_path, query_id=True, dtype=np.float32
        )
        y_train = y_train.astype(np.int32)
        qid_train = qid_train.astype(np.int32)

        X_valid, y_valid, qid_valid = load_svmlight_file(
            valid_path, query_id=True, dtype=np.float32
        )
        y_valid = y_valid.astype(np.int32)
        qid_valid = qid_valid.astype(np.int32)

        X_test, y_test, qid_test = load_svmlight_file(
            test_path, query_id=True, dtype=np.float32
        )
        y_test = y_test.astype(np.int32)
        qid_test = qid_test.astype(np.int32)

        data = RelDataCV(
            train=(X_train, y_train, qid_train),
            test=(X_test, y_test, qid_test),
            max_rel=4,
        )

        with open(cache_path, "wb") as fd:
            pkl.dump(data, fd)

    with open(cache_path, "rb") as fd:
        data = pkl.load(fd)

    return data

# %%
def ranking_demo():
    """Demonstration for learning to rank with relevance degree."""
    data = load_mlsr_10k('C:\MSLR-WEB10K', 'C:\MSLR-WEB10K-cache')

    # Sort data according to query index
    X_train, y_train, qid_train = data.train
    sorted_idx = np.argsort(qid_train)
    X_train = X_train[sorted_idx]
    y_train = y_train[sorted_idx]
    qid_train = qid_train[sorted_idx]

    X_test, y_test, qid_test = data.test
    sorted_idx = np.argsort(qid_test)
    X_test = X_test[sorted_idx]
    y_test = y_test[sorted_idx]
    qid_test = qid_test[sorted_idx]

    ranker = xgb.XGBRanker(
        tree_method="hist",
        device="cuda",
        lambdarank_pair_method="mean",
        lambdarank_num_pair_per_sample=5,
        eval_metric=["ndcg@1", "ndcg@8"],
    )
    ranker.fit(
        X_train,
        y_train,
        qid=qid_train,
        eval_set=[(X_test, y_test)],
        eval_qid=[qid_test],
        verbose=True,
    )
    # Save the model
    model_IR = "ranker_model.json"
    ranker.save_model(model_IR)

    return ranker, X_train, y_train, qid_train, X_test, y_test, qid_test, model_IR 

ranker, X_train, y_train, qid_train, X_test, y_test, qid_test, model_IR = ranking_demo()
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [23:15:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\context.cc:44: No visible GPU is found, setting device to CPU.
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-ndcg@1:0.37069	validation_0-ndcg@8:0.39967
# [1]	validation_0-ndcg@1:0.41020	validation_0-ndcg@8:0.42229
# [2]	validation_0-ndcg@1:0.41790	validation_0-ndcg@8:0.43076
# [3]	validation_0-ndcg@1:0.43181	validation_0-ndcg@8:0.43708
# [4]	validation_0-ndcg@1:0.43819	validation_0-ndcg@8:0.44078
# [5]	validation_0-ndcg@1:0.44350	validation_0-ndcg@8:0.44393
# [6]	validation_0-ndcg@1:0.44400	validation_0-ndcg@8:0.44659
# [7]	validation_0-ndcg@1:0.44378	validation_0-ndcg@8:0.44911
# [8]	validation_0-ndcg@1:0.44407	validation_0-ndcg@8:0.45207
# [9]	validation_0-ndcg@1:0.44843	validation_0-ndcg@8:0.45476
# [10]	validation_0-ndcg@1:0.44948	validation_0-ndcg@8:0.45637
# [11]	validation_0-ndcg@1:0.45174	validation_0-ndcg@8:0.45920
# [12]	validation_0-ndcg@1:0.45643	validation_0-ndcg@8:0.46284
# [13]	validation_0-ndcg@1:0.45774	validation_0-ndcg@8:0.46476
# [14]	validation_0-ndcg@1:0.45888	validation_0-ndcg@8:0.46543
# [15]	validation_0-ndcg@1:0.45863	validation_0-ndcg@8:0.46742
# [16]	validation_0-ndcg@1:0.46047	validation_0-ndcg@8:0.46768
# [17]	validation_0-ndcg@1:0.46325	validation_0-ndcg@8:0.46872
# [18]	validation_0-ndcg@1:0.46817	validation_0-ndcg@8:0.47096
# [19]	validation_0-ndcg@1:0.46870	validation_0-ndcg@8:0.47299
# [20]	validation_0-ndcg@1:0.46689	validation_0-ndcg@8:0.47392
# [21]	validation_0-ndcg@1:0.47034	validation_0-ndcg@8:0.47560
# [22]	validation_0-ndcg@1:0.46883	validation_0-ndcg@8:0.47598
# [23]	validation_0-ndcg@1:0.46947	validation_0-ndcg@8:0.47652
# [24]	validation_0-ndcg@1:0.46958	validation_0-ndcg@8:0.47714
# [25]	validation_0-ndcg@1:0.47343	validation_0-ndcg@8:0.47798
# [26]	validation_0-ndcg@1:0.47470	validation_0-ndcg@8:0.47863
# [27]	validation_0-ndcg@1:0.47554	validation_0-ndcg@8:0.47860
# [28]	validation_0-ndcg@1:0.47248	validation_0-ndcg@8:0.47803
# [29]	validation_0-ndcg@1:0.47774	validation_0-ndcg@8:0.48010
# [30]	validation_0-ndcg@1:0.47547	validation_0-ndcg@8:0.48123
# [31]	validation_0-ndcg@1:0.47511	validation_0-ndcg@8:0.48207
# [32]	validation_0-ndcg@1:0.47614	validation_0-ndcg@8:0.48253
# [33]	validation_0-ndcg@1:0.47566	validation_0-ndcg@8:0.48210
# [34]	validation_0-ndcg@1:0.47557	validation_0-ndcg@8:0.48164
# [35]	validation_0-ndcg@1:0.47755	validation_0-ndcg@8:0.48299
# [36]	validation_0-ndcg@1:0.47839	validation_0-ndcg@8:0.48340
# [37]	validation_0-ndcg@1:0.47647	validation_0-ndcg@8:0.48300
# [38]	validation_0-ndcg@1:0.47760	validation_0-ndcg@8:0.48260
# [39]	validation_0-ndcg@1:0.47774	validation_0-ndcg@8:0.48426
# [40]	validation_0-ndcg@1:0.47625	validation_0-ndcg@8:0.48401
# [41]	validation_0-ndcg@1:0.47636	validation_0-ndcg@8:0.48491
# [42]	validation_0-ndcg@1:0.47932	validation_0-ndcg@8:0.48578
# [43]	validation_0-ndcg@1:0.47782	validation_0-ndcg@8:0.48540
# [44]	validation_0-ndcg@1:0.47577	validation_0-ndcg@8:0.48604
# [45]	validation_0-ndcg@1:0.47533	validation_0-ndcg@8:0.48593
# [46]	validation_0-ndcg@1:0.47751	validation_0-ndcg@8:0.48653
# [47]	validation_0-ndcg@1:0.47742	validation_0-ndcg@8:0.48637
# [48]	validation_0-ndcg@1:0.47705	validation_0-ndcg@8:0.48651
# [49]	validation_0-ndcg@1:0.47767	validation_0-ndcg@8:0.48646
# [50]	validation_0-ndcg@1:0.47314	validation_0-ndcg@8:0.48579
# [51]	validation_0-ndcg@1:0.47259	validation_0-ndcg@8:0.48638
# [52]	validation_0-ndcg@1:0.47385	validation_0-ndcg@8:0.48684
# [53]	validation_0-ndcg@1:0.47362	validation_0-ndcg@8:0.48709
# [54]	validation_0-ndcg@1:0.47431	validation_0-ndcg@8:0.48764
# [55]	validation_0-ndcg@1:0.47358	validation_0-ndcg@8:0.48759
# [56]	validation_0-ndcg@1:0.47390	validation_0-ndcg@8:0.48876
# [57]	validation_0-ndcg@1:0.47342	validation_0-ndcg@8:0.48886
# [58]	validation_0-ndcg@1:0.47281	validation_0-ndcg@8:0.48863
# [59]	validation_0-ndcg@1:0.47366	validation_0-ndcg@8:0.48879
# [60]	validation_0-ndcg@1:0.47369	validation_0-ndcg@8:0.48935
# [61]	validation_0-ndcg@1:0.47334	validation_0-ndcg@8:0.48917
# [62]	validation_0-ndcg@1:0.47294	validation_0-ndcg@8:0.48883
# [63]	validation_0-ndcg@1:0.47530	validation_0-ndcg@8:0.48880
# [64]	validation_0-ndcg@1:0.47596	validation_0-ndcg@8:0.48903
# [65]	validation_0-ndcg@1:0.47649	validation_0-ndcg@8:0.48961
# [66]	validation_0-ndcg@1:0.47619	validation_0-ndcg@8:0.48946
# [67]	validation_0-ndcg@1:0.47726	validation_0-ndcg@8:0.48958
# [68]	validation_0-ndcg@1:0.47794	validation_0-ndcg@8:0.48937
# [69]	validation_0-ndcg@1:0.47551	validation_0-ndcg@8:0.48874
# [70]	validation_0-ndcg@1:0.47752	validation_0-ndcg@8:0.48947
# [71]	validation_0-ndcg@1:0.47602	validation_0-ndcg@8:0.48912
# [72]	validation_0-ndcg@1:0.47513	validation_0-ndcg@8:0.48964
# [73]	validation_0-ndcg@1:0.47508	validation_0-ndcg@8:0.48943
# [74]	validation_0-ndcg@1:0.47359	validation_0-ndcg@8:0.48951
# [75]	validation_0-ndcg@1:0.47256	validation_0-ndcg@8:0.48951
# [76]	validation_0-ndcg@1:0.47263	validation_0-ndcg@8:0.48960
# [77]	validation_0-ndcg@1:0.47044	validation_0-ndcg@8:0.48953
# [78]	validation_0-ndcg@1:0.46967	validation_0-ndcg@8:0.48950
# [79]	validation_0-ndcg@1:0.47035	validation_0-ndcg@8:0.48896
# [80]	validation_0-ndcg@1:0.47064	validation_0-ndcg@8:0.48931
# [81]	validation_0-ndcg@1:0.46908	validation_0-ndcg@8:0.48877
# [82]	validation_0-ndcg@1:0.47129	validation_0-ndcg@8:0.48916
# [83]	validation_0-ndcg@1:0.47152	validation_0-ndcg@8:0.48872
# [84]	validation_0-ndcg@1:0.47178	validation_0-ndcg@8:0.48843
# [85]	validation_0-ndcg@1:0.47197	validation_0-ndcg@8:0.48883
# [86]	validation_0-ndcg@1:0.47252	validation_0-ndcg@8:0.48890
# [87]	validation_0-ndcg@1:0.47495	validation_0-ndcg@8:0.48962
# [88]	validation_0-ndcg@1:0.47526	validation_0-ndcg@8:0.48969
# [89]	validation_0-ndcg@1:0.47405	validation_0-ndcg@8:0.48953
# [90]	validation_0-ndcg@1:0.47564	validation_0-ndcg@8:0.49021
# [91]	validation_0-ndcg@1:0.47493	validation_0-ndcg@8:0.49039
# [92]	validation_0-ndcg@1:0.47403	validation_0-ndcg@8:0.48990
# [93]	validation_0-ndcg@1:0.47320	validation_0-ndcg@8:0.48950
# [94]	validation_0-ndcg@1:0.47337	validation_0-ndcg@8:0.48937
# [95]	validation_0-ndcg@1:0.47290	validation_0-ndcg@8:0.48870
# [96]	validation_0-ndcg@1:0.47403	validation_0-ndcg@8:0.48895
# [97]	validation_0-ndcg@1:0.47424	validation_0-ndcg@8:0.48907
# [98]	validation_0-ndcg@1:0.47424	validation_0-ndcg@8:0.48900
# [99]	validation_0-ndcg@1:0.47393	validation_0-ndcg@8:0.48904

# %% [markdown]
# ### Exercises
# 1) save the generated model into disk
# 2) load the generated model from disk
# 3) use the `predict` method and try it on a number of samples
# 4) compare the performance of a numer of methods: rank:ndcg (default), rank:map, and rank:pairwise
#    https://xgboost.readthedocs.io/en/stable/parameter.html#learning-task-parameters

# %%
#load the model
loaded_ranker = xgb.XGBRanker()
loaded_ranker.load_model(model_IR)

# %%
n_samples = 8 
sample_test_data = X_test[:n_samples]
predictions = loaded_ranker.predict(sample_test_data)
print("Predictions:", predictions)
# Out:
# Predictions: [-0.49255788 -0.02598316 -0.55691683  0.22683729  0.26758316  1.0661651
#   0.31244534  0.45037895]

# %%
import numpy as np

def to_binary_labels(y, threshold=None):
    if threshold is not None:
        return np.where(y > threshold, 1, 0)
    else:
        return y 

def train_and_evaluate(objective, X_train, y_train, qid_train, X_test, y_test, qid_test, threshold=None):
    # Convert labels
    y_train_bin = to_binary_labels(y_train, threshold)
    y_test_bin = to_binary_labels(y_test, threshold)

    ranker = xgb.XGBRanker(
        tree_method="hist",
        objective=objective,
        eval_metric=["ndcg@1", "ndcg@8"],
    )
    ranker.fit(
        X_train,
        y_train_bin,
        qid=qid_train,
        eval_set=[(X_test, y_test_bin)],
        eval_qid=[qid_test],
        verbose=True,
    )
    predictions = ranker.predict(X_test)
    score = ndcg_score([y_test_bin], [predictions])

    return score

threshold = 2
ndcg_score_ndcg = train_and_evaluate("rank:ndcg", X_train, y_train, qid_train, X_test, y_test, qid_test)
ndcg_score_map = train_and_evaluate("rank:map", X_train, y_train, qid_train, X_test, y_test, qid_test, threshold)
ndcg_score_pairwise = train_and_evaluate("rank:pairwise", X_train, y_train, qid_train, X_test, y_test, qid_test)

#performances
print("rank:ndcg score:", ndcg_score_ndcg)
print("rank:map score:", ndcg_score_map)
print("rank:pairwise score:", ndcg_score_pairwise)
# Out:
# [0]	validation_0-ndcg@1:0.38987	validation_0-ndcg@8:0.40893
# [1]	validation_0-ndcg@1:0.42807	validation_0-ndcg@8:0.43250
# [2]	validation_0-ndcg@1:0.43772	validation_0-ndcg@8:0.43896
# [3]	validation_0-ndcg@1:0.43785	validation_0-ndcg@8:0.44395
# [4]	validation_0-ndcg@1:0.44232	validation_0-ndcg@8:0.44802
# [5]	validation_0-ndcg@1:0.44810	validation_0-ndcg@8:0.44963
# [6]	validation_0-ndcg@1:0.45144	validation_0-ndcg@8:0.45352
# [7]	validation_0-ndcg@1:0.44869	validation_0-ndcg@8:0.45500
# [8]	validation_0-ndcg@1:0.45181	validation_0-ndcg@8:0.45665
# [9]	validation_0-ndcg@1:0.45338	validation_0-ndcg@8:0.45892
# [10]	validation_0-ndcg@1:0.45278	validation_0-ndcg@8:0.46004
# [11]	validation_0-ndcg@1:0.45642	validation_0-ndcg@8:0.46283
# [12]	validation_0-ndcg@1:0.46048	validation_0-ndcg@8:0.46618
# [13]	validation_0-ndcg@1:0.46480	validation_0-ndcg@8:0.46843
# [14]	validation_0-ndcg@1:0.46542	validation_0-ndcg@8:0.46962
# [15]	validation_0-ndcg@1:0.46223	validation_0-ndcg@8:0.47151
# [16]	validation_0-ndcg@1:0.46688	validation_0-ndcg@8:0.47401
# [17]	validation_0-ndcg@1:0.47258	validation_0-ndcg@8:0.47634
# [18]	validation_0-ndcg@1:0.47490	validation_0-ndcg@8:0.47868
# [19]	validation_0-ndcg@1:0.47683	validation_0-ndcg@8:0.47977
# [20]	validation_0-ndcg@1:0.47486	validation_0-ndcg@8:0.48072
# [21]	validation_0-ndcg@1:0.47840	validation_0-ndcg@8:0.48209
# [22]	validation_0-ndcg@1:0.47836	validation_0-ndcg@8:0.48330
# [23]	validation_0-ndcg@1:0.47922	validation_0-ndcg@8:0.48253
# [24]	validation_0-ndcg@1:0.48454	validation_0-ndcg@8:0.48475
# [25]	validation_0-ndcg@1:0.48726	validation_0-ndcg@8:0.48464
# [26]	validation_0-ndcg@1:0.48588	validation_0-ndcg@8:0.48506
# [27]	validation_0-ndcg@1:0.48397	validation_0-ndcg@8:0.48570
# [28]	validation_0-ndcg@1:0.48191	validation_0-ndcg@8:0.48639
# [29]	validation_0-ndcg@1:0.48102	validation_0-ndcg@8:0.48723
# [30]	validation_0-ndcg@1:0.48013	validation_0-ndcg@8:0.48762
# [31]	validation_0-ndcg@1:0.48000	validation_0-ndcg@8:0.48789
# [32]	validation_0-ndcg@1:0.48132	validation_0-ndcg@8:0.48884
# [33]	validation_0-ndcg@1:0.48307	validation_0-ndcg@8:0.48796
# [34]	validation_0-ndcg@1:0.48506	validation_0-ndcg@8:0.48967
# [35]	validation_0-ndcg@1:0.48515	validation_0-ndcg@8:0.48984
# [36]	validation_0-ndcg@1:0.48585	validation_0-ndcg@8:0.48989
# [37]	validation_0-ndcg@1:0.49070	validation_0-ndcg@8:0.49098
# [38]	validation_0-ndcg@1:0.49248	validation_0-ndcg@8:0.49173
# [39]	validation_0-ndcg@1:0.49027	validation_0-ndcg@8:0.49193
# [40]	validation_0-ndcg@1:0.48993	validation_0-ndcg@8:0.49186
# [41]	validation_0-ndcg@1:0.49118	validation_0-ndcg@8:0.49235
# [42]	validation_0-ndcg@1:0.48698	validation_0-ndcg@8:0.49189
# [43]	validation_0-ndcg@1:0.48808	validation_0-ndcg@8:0.49148
# [44]	validation_0-ndcg@1:0.49040	validation_0-ndcg@8:0.49138
# [45]	validation_0-ndcg@1:0.48935	validation_0-ndcg@8:0.49122
# [46]	validation_0-ndcg@1:0.49024	validation_0-ndcg@8:0.49179
# [47]	validation_0-ndcg@1:0.48943	validation_0-ndcg@8:0.49222
# [48]	validation_0-ndcg@1:0.49070	validation_0-ndcg@8:0.49245
# [49]	validation_0-ndcg@1:0.48923	validation_0-ndcg@8:0.49233
# [50]	validation_0-ndcg@1:0.48594	validation_0-ndcg@8:0.49204
# [51]	validation_0-ndcg@1:0.48804	validation_0-ndcg@8:0.49319
# [52]	validation_0-ndcg@1:0.48711	validation_0-ndcg@8:0.49270
# [53]	validation_0-ndcg@1:0.48598	validation_0-ndcg@8:0.49309
# [54]	validation_0-ndcg@1:0.48891	validation_0-ndcg@8:0.49338
# [55]	validation_0-ndcg@1:0.48902	validation_0-ndcg@8:0.49344
# [56]	validation_0-ndcg@1:0.49028	validation_0-ndcg@8:0.49493
# [57]	validation_0-ndcg@1:0.48966	validation_0-ndcg@8:0.49553
# [58]	validation_0-ndcg@1:0.48832	validation_0-ndcg@8:0.49524
# [59]	validation_0-ndcg@1:0.48742	validation_0-ndcg@8:0.49599
# [60]	validation_0-ndcg@1:0.48821	validation_0-ndcg@8:0.49535
# [61]	validation_0-ndcg@1:0.48870	validation_0-ndcg@8:0.49501
# [62]	validation_0-ndcg@1:0.48858	validation_0-ndcg@8:0.49511
# [63]	validation_0-ndcg@1:0.48812	validation_0-ndcg@8:0.49536
# [64]	validation_0-ndcg@1:0.48830	validation_0-ndcg@8:0.49585
# [65]	validation_0-ndcg@1:0.48752	validation_0-ndcg@8:0.49549
# [66]	validation_0-ndcg@1:0.48960	validation_0-ndcg@8:0.49590
# [67]	validation_0-ndcg@1:0.49028	validation_0-ndcg@8:0.49556
# [68]	validation_0-ndcg@1:0.49015	validation_0-ndcg@8:0.49556
# [69]	validation_0-ndcg@1:0.48913	validation_0-ndcg@8:0.49533
# [70]	validation_0-ndcg@1:0.49061	validation_0-ndcg@8:0.49540
# [71]	validation_0-ndcg@1:0.49015	validation_0-ndcg@8:0.49551
# [72]	validation_0-ndcg@1:0.49063	validation_0-ndcg@8:0.49586
# [73]	validation_0-ndcg@1:0.49305	validation_0-ndcg@8:0.49566
# [74]	validation_0-ndcg@1:0.49328	validation_0-ndcg@8:0.49591
# [75]	validation_0-ndcg@1:0.49407	validation_0-ndcg@8:0.49690
# [76]	validation_0-ndcg@1:0.49474	validation_0-ndcg@8:0.49739
# [77]	validation_0-ndcg@1:0.49570	validation_0-ndcg@8:0.49786
# [78]	validation_0-ndcg@1:0.49406	validation_0-ndcg@8:0.49772
# [79]	validation_0-ndcg@1:0.49359	validation_0-ndcg@8:0.49739
# [80]	validation_0-ndcg@1:0.49490	validation_0-ndcg@8:0.49742
# [81]	validation_0-ndcg@1:0.49354	validation_0-ndcg@8:0.49751
# [82]	validation_0-ndcg@1:0.49496	validation_0-ndcg@8:0.49764
# [83]	validation_0-ndcg@1:0.49339	validation_0-ndcg@8:0.49727
# [84]	validation_0-ndcg@1:0.49185	validation_0-ndcg@8:0.49700
# [85]	validation_0-ndcg@1:0.49241	validation_0-ndcg@8:0.49726
# [86]	validation_0-ndcg@1:0.49163	validation_0-ndcg@8:0.49702
# [87]	validation_0-ndcg@1:0.49208	validation_0-ndcg@8:0.49722
# [88]	validation_0-ndcg@1:0.49191	validation_0-ndcg@8:0.49711
# [89]	validation_0-ndcg@1:0.49275	validation_0-ndcg@8:0.49722
# [90]	validation_0-ndcg@1:0.49097	validation_0-ndcg@8:0.49721
# [91]	validation_0-ndcg@1:0.48954	validation_0-ndcg@8:0.49714
# [92]	validation_0-ndcg@1:0.48843	validation_0-ndcg@8:0.49700
# [93]	validation_0-ndcg@1:0.48792	validation_0-ndcg@8:0.49719
# [94]	validation_0-ndcg@1:0.48673	validation_0-ndcg@8:0.49695
# [95]	validation_0-ndcg@1:0.48649	validation_0-ndcg@8:0.49723
# [96]	validation_0-ndcg@1:0.48720	validation_0-ndcg@8:0.49749
# [97]	validation_0-ndcg@1:0.48708	validation_0-ndcg@8:0.49759
# [98]	validation_0-ndcg@1:0.48585	validation_0-ndcg@8:0.49712
# [99]	validation_0-ndcg@1:0.48720	validation_0-ndcg@8:0.49741
# [0]	validation_0-ndcg@1:0.54050	validation_0-ndcg@8:0.52839
# [1]	validation_0-ndcg@1:0.56950	validation_0-ndcg@8:0.54780
# [2]	validation_0-ndcg@1:0.58100	validation_0-ndcg@8:0.55430
# [3]	validation_0-ndcg@1:0.58050	validation_0-ndcg@8:0.55979
# [4]	validation_0-ndcg@1:0.59350	validation_0-ndcg@8:0.56533
# [5]	validation_0-ndcg@1:0.59300	validation_0-ndcg@8:0.56561
# [6]	validation_0-ndcg@1:0.59650	validation_0-ndcg@8:0.56706
# [7]	validation_0-ndcg@1:0.60900	validation_0-ndcg@8:0.57164
# [8]	validation_0-ndcg@1:0.60350	validation_0-ndcg@8:0.57311
# [9]	validation_0-ndcg@1:0.60500	validation_0-ndcg@8:0.57419
# [10]	validation_0-ndcg@1:0.60650	validation_0-ndcg@8:0.57575
# [11]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.57626
# [12]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.57813
# [13]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.57952
# [14]	validation_0-ndcg@1:0.61500	validation_0-ndcg@8:0.58180
# [15]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.58332
# [16]	validation_0-ndcg@1:0.61300	validation_0-ndcg@8:0.58412
# [17]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.58538
# [18]	validation_0-ndcg@1:0.61650	validation_0-ndcg@8:0.58624
# [19]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.58615
# [20]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.58640
# [21]	validation_0-ndcg@1:0.61650	validation_0-ndcg@8:0.58868
# [22]	validation_0-ndcg@1:0.61650	validation_0-ndcg@8:0.58915
# [23]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.58804
# [24]	validation_0-ndcg@1:0.61650	validation_0-ndcg@8:0.58976
# [25]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.59018
# [26]	validation_0-ndcg@1:0.61600	validation_0-ndcg@8:0.59136
# [27]	validation_0-ndcg@1:0.61500	validation_0-ndcg@8:0.59044
# [28]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.59083
# [29]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.59062
# [30]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.59135
# [31]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.59130
# [32]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.59244
# [33]	validation_0-ndcg@1:0.61550	validation_0-ndcg@8:0.59212
# [34]	validation_0-ndcg@1:0.61500	validation_0-ndcg@8:0.59311
# [35]	validation_0-ndcg@1:0.61500	validation_0-ndcg@8:0.59259
# [36]	validation_0-ndcg@1:0.61700	validation_0-ndcg@8:0.59281
# [37]	validation_0-ndcg@1:0.61700	validation_0-ndcg@8:0.59289
# [38]	validation_0-ndcg@1:0.61900	validation_0-ndcg@8:0.59326
# [39]	validation_0-ndcg@1:0.61500	validation_0-ndcg@8:0.59358
# [40]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.59210
# [41]	validation_0-ndcg@1:0.61450	validation_0-ndcg@8:0.59224
# [42]	validation_0-ndcg@1:0.61550	validation_0-ndcg@8:0.59294
# [43]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.59296
# [44]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.59267
# [45]	validation_0-ndcg@1:0.61200	validation_0-ndcg@8:0.59244
# [46]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59284
# [47]	validation_0-ndcg@1:0.61250	validation_0-ndcg@8:0.59299
# [48]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59296
# [49]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59241
# [50]	validation_0-ndcg@1:0.61000	validation_0-ndcg@8:0.59231
# [51]	validation_0-ndcg@1:0.61400	validation_0-ndcg@8:0.59365
# [52]	validation_0-ndcg@1:0.61250	validation_0-ndcg@8:0.59283
# [53]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59307
# [54]	validation_0-ndcg@1:0.61200	validation_0-ndcg@8:0.59272
# [55]	validation_0-ndcg@1:0.61200	validation_0-ndcg@8:0.59258
# [56]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.59292
# [57]	validation_0-ndcg@1:0.61300	validation_0-ndcg@8:0.59261
# [58]	validation_0-ndcg@1:0.61250	validation_0-ndcg@8:0.59246
# [59]	validation_0-ndcg@1:0.61300	validation_0-ndcg@8:0.59299
# [60]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.59265
# [61]	validation_0-ndcg@1:0.61350	validation_0-ndcg@8:0.59269
# [62]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59233
# [63]	validation_0-ndcg@1:0.61250	validation_0-ndcg@8:0.59232
# [64]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59221
# [65]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59207
# [66]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59186
# [67]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59189
# [68]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59191
# [69]	validation_0-ndcg@1:0.61000	validation_0-ndcg@8:0.59185
# [70]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59215
# [71]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59215
# [72]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59203
# [73]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59191
# [74]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59184
# [75]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59205
# [76]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59198
# [77]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59213
# [78]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59221
# [79]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59291
# [80]	validation_0-ndcg@1:0.61150	validation_0-ndcg@8:0.59281
# [81]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59303
# [82]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59264
# [83]	validation_0-ndcg@1:0.61200	validation_0-ndcg@8:0.59246
# [84]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59118
# [85]	validation_0-ndcg@1:0.61000	validation_0-ndcg@8:0.59170
# [86]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59164
# [87]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59159
# [88]	validation_0-ndcg@1:0.60900	validation_0-ndcg@8:0.59147
# [89]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59167
# [90]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59138
# [91]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59109
# [92]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59155
# [93]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59173
# [94]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59154
# [95]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59110
# [96]	validation_0-ndcg@1:0.60950	validation_0-ndcg@8:0.59071
# [97]	validation_0-ndcg@1:0.61100	validation_0-ndcg@8:0.59115
# [98]	validation_0-ndcg@1:0.61050	validation_0-ndcg@8:0.59125
# [99]	validation_0-ndcg@1:0.61200	validation_0-ndcg@8:0.59156
# [0]	validation_0-ndcg@1:0.38211	validation_0-ndcg@8:0.40190
# [1]	validation_0-ndcg@1:0.40322	validation_0-ndcg@8:0.42253
# [2]	validation_0-ndcg@1:0.41535	validation_0-ndcg@8:0.43429
# [3]	validation_0-ndcg@1:0.42115	validation_0-ndcg@8:0.43889
# [4]	validation_0-ndcg@1:0.42629	validation_0-ndcg@8:0.44462
# [5]	validation_0-ndcg@1:0.43113	validation_0-ndcg@8:0.44932
# [6]	validation_0-ndcg@1:0.43300	validation_0-ndcg@8:0.45108
# [7]	validation_0-ndcg@1:0.43017	validation_0-ndcg@8:0.45286
# [8]	validation_0-ndcg@1:0.43140	validation_0-ndcg@8:0.45477
# [9]	validation_0-ndcg@1:0.43447	validation_0-ndcg@8:0.45888
# [10]	validation_0-ndcg@1:0.43695	validation_0-ndcg@8:0.45989
# [11]	validation_0-ndcg@1:0.43650	validation_0-ndcg@8:0.46162
# [12]	validation_0-ndcg@1:0.43449	validation_0-ndcg@8:0.46242
# [13]	validation_0-ndcg@1:0.43551	validation_0-ndcg@8:0.46419
# [14]	validation_0-ndcg@1:0.43397	validation_0-ndcg@8:0.46520
# [15]	validation_0-ndcg@1:0.44001	validation_0-ndcg@8:0.46715
# [16]	validation_0-ndcg@1:0.44220	validation_0-ndcg@8:0.46857
# [17]	validation_0-ndcg@1:0.44078	validation_0-ndcg@8:0.46952
# [18]	validation_0-ndcg@1:0.44409	validation_0-ndcg@8:0.46972
# [19]	validation_0-ndcg@1:0.44565	validation_0-ndcg@8:0.47109
# [20]	validation_0-ndcg@1:0.45067	validation_0-ndcg@8:0.47150
# [21]	validation_0-ndcg@1:0.44713	validation_0-ndcg@8:0.47207
# [22]	validation_0-ndcg@1:0.44810	validation_0-ndcg@8:0.47179
# [23]	validation_0-ndcg@1:0.44497	validation_0-ndcg@8:0.47176
# [24]	validation_0-ndcg@1:0.44561	validation_0-ndcg@8:0.47284
# [25]	validation_0-ndcg@1:0.44851	validation_0-ndcg@8:0.47362
# [26]	validation_0-ndcg@1:0.44910	validation_0-ndcg@8:0.47419
# [27]	validation_0-ndcg@1:0.45051	validation_0-ndcg@8:0.47479
# [28]	validation_0-ndcg@1:0.45216	validation_0-ndcg@8:0.47508
# [29]	validation_0-ndcg@1:0.45360	validation_0-ndcg@8:0.47574
# [30]	validation_0-ndcg@1:0.45796	validation_0-ndcg@8:0.47678
# [31]	validation_0-ndcg@1:0.46026	validation_0-ndcg@8:0.47701
# [32]	validation_0-ndcg@1:0.46034	validation_0-ndcg@8:0.47737
# [33]	validation_0-ndcg@1:0.46036	validation_0-ndcg@8:0.47813
# [34]	validation_0-ndcg@1:0.45625	validation_0-ndcg@8:0.47785
# [35]	validation_0-ndcg@1:0.45879	validation_0-ndcg@8:0.47808
# [36]	validation_0-ndcg@1:0.45856	validation_0-ndcg@8:0.47890
# [37]	validation_0-ndcg@1:0.46001	validation_0-ndcg@8:0.47889
# [38]	validation_0-ndcg@1:0.45879	validation_0-ndcg@8:0.47868
# [39]	validation_0-ndcg@1:0.45554	validation_0-ndcg@8:0.47781
# [40]	validation_0-ndcg@1:0.45670	validation_0-ndcg@8:0.47875
# [41]	validation_0-ndcg@1:0.45737	validation_0-ndcg@8:0.47905
# [42]	validation_0-ndcg@1:0.45518	validation_0-ndcg@8:0.47913
# [43]	validation_0-ndcg@1:0.45390	validation_0-ndcg@8:0.47848
# [44]	validation_0-ndcg@1:0.45380	validation_0-ndcg@8:0.47911
# [45]	validation_0-ndcg@1:0.45523	validation_0-ndcg@8:0.47949
# [46]	validation_0-ndcg@1:0.45854	validation_0-ndcg@8:0.47990
# [47]	validation_0-ndcg@1:0.45605	validation_0-ndcg@8:0.47923
# [48]	validation_0-ndcg@1:0.45669	validation_0-ndcg@8:0.47962
# [49]	validation_0-ndcg@1:0.45722	validation_0-ndcg@8:0.48035
# [50]	validation_0-ndcg@1:0.45895	validation_0-ndcg@8:0.48080
# [51]	validation_0-ndcg@1:0.45739	validation_0-ndcg@8:0.48122
# [52]	validation_0-ndcg@1:0.45802	validation_0-ndcg@8:0.48056
# [53]	validation_0-ndcg@1:0.45979	validation_0-ndcg@8:0.48076
# [54]	validation_0-ndcg@1:0.45899	validation_0-ndcg@8:0.48116
# [55]	validation_0-ndcg@1:0.45803	validation_0-ndcg@8:0.48156
# [56]	validation_0-ndcg@1:0.45894	validation_0-ndcg@8:0.48086
# [57]	validation_0-ndcg@1:0.45987	validation_0-ndcg@8:0.48110
# [58]	validation_0-ndcg@1:0.46128	validation_0-ndcg@8:0.48174
# [59]	validation_0-ndcg@1:0.46062	validation_0-ndcg@8:0.48185
# [60]	validation_0-ndcg@1:0.45916	validation_0-ndcg@8:0.48166
# [61]	validation_0-ndcg@1:0.46107	validation_0-ndcg@8:0.48223
# [62]	validation_0-ndcg@1:0.46019	validation_0-ndcg@8:0.48173
# [63]	validation_0-ndcg@1:0.46101	validation_0-ndcg@8:0.48224
# [64]	validation_0-ndcg@1:0.46065	validation_0-ndcg@8:0.48163
# [65]	validation_0-ndcg@1:0.46340	validation_0-ndcg@8:0.48231
# [66]	validation_0-ndcg@1:0.46484	validation_0-ndcg@8:0.48250
# [67]	validation_0-ndcg@1:0.46817	validation_0-ndcg@8:0.48324
# [68]	validation_0-ndcg@1:0.46534	validation_0-ndcg@8:0.48260
# [69]	validation_0-ndcg@1:0.46537	validation_0-ndcg@8:0.48232
# [70]	validation_0-ndcg@1:0.46491	validation_0-ndcg@8:0.48212
# [71]	validation_0-ndcg@1:0.46638	validation_0-ndcg@8:0.48270
# [72]	validation_0-ndcg@1:0.46525	validation_0-ndcg@8:0.48236
# [73]	validation_0-ndcg@1:0.46474	validation_0-ndcg@8:0.48244
# [74]	validation_0-ndcg@1:0.46421	validation_0-ndcg@8:0.48278
# [75]	validation_0-ndcg@1:0.46426	validation_0-ndcg@8:0.48276
# [76]	validation_0-ndcg@1:0.46466	validation_0-ndcg@8:0.48253
# [77]	validation_0-ndcg@1:0.46272	validation_0-ndcg@8:0.48281
# [78]	validation_0-ndcg@1:0.46292	validation_0-ndcg@8:0.48299
# [79]	validation_0-ndcg@1:0.46363	validation_0-ndcg@8:0.48294
# [80]	validation_0-ndcg@1:0.46609	validation_0-ndcg@8:0.48307
# [81]	validation_0-ndcg@1:0.46515	validation_0-ndcg@8:0.48280
# [82]	validation_0-ndcg@1:0.46759	validation_0-ndcg@8:0.48341
# [83]	validation_0-ndcg@1:0.46540	validation_0-ndcg@8:0.48342
# [84]	validation_0-ndcg@1:0.46521	validation_0-ndcg@8:0.48337
# [85]	validation_0-ndcg@1:0.46468	validation_0-ndcg@8:0.48297
# [86]	validation_0-ndcg@1:0.46507	validation_0-ndcg@8:0.48296
# [87]	validation_0-ndcg@1:0.46520	validation_0-ndcg@8:0.48279
# [88]	validation_0-ndcg@1:0.46594	validation_0-ndcg@8:0.48316
# [89]	validation_0-ndcg@1:0.46508	validation_0-ndcg@8:0.48329
# [90]	validation_0-ndcg@1:0.46418	validation_0-ndcg@8:0.48302
# [91]	validation_0-ndcg@1:0.46255	validation_0-ndcg@8:0.48243
# [92]	validation_0-ndcg@1:0.46212	validation_0-ndcg@8:0.48262
# [93]	validation_0-ndcg@1:0.46239	validation_0-ndcg@8:0.48277
# [94]	validation_0-ndcg@1:0.46041	validation_0-ndcg@8:0.48311
# [95]	validation_0-ndcg@1:0.46309	validation_0-ndcg@8:0.48383
# [96]	validation_0-ndcg@1:0.46490	validation_0-ndcg@8:0.48406
# [97]	validation_0-ndcg@1:0.46553	validation_0-ndcg@8:0.48408
# [98]	validation_0-ndcg@1:0.46572	validation_0-ndcg@8:0.48391
# [99]	validation_0-ndcg@1:0.46599	validation_0-ndcg@8:0.48418
# NDCG score for rank:ndcg: 0.9370640460262063
# NDCG score for rank:map: 0.8022895563366288
# NDCG score for rank:pairwise: 0.9368783974674743
